# %% [markdown]
# ## Follower Counts
# - Min: 15,959 (log is 4.2)
# - Max: 19,199,185 (log is 7.28)
# - Total Streamers: 182 (all)
#
# ## All-Time High Subscriber Counts
# - Min: 897
# - Max: 728,535
# - Total Streamers: 175
# > Missing from: broxh_ , Chap , Duke , LTANorth , Nadia , Rainbow6 , Valkyrae
#
# ## Current Subscriber Counts:
# - Min: 0
# - Max: 60,469
# (not good)
#
# ## Bin Ranges
# Bin 0 range: 16,329.999 to 1,034,764.667
# Bin 1 range: 1,034,764.667 to 1,848,768.667
# Bin 2 range: 1,848,768.667 to 19,201,884.0

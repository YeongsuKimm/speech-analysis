# %% [markdown]
# # Training Regression

# %% [markdown]
# ### 70-30 Split
# #### Normalized (lr:1e-2)
# Epoch 1/30, Train Loss: 0.1589, Val Loss: 0.2017
# Epoch 2/30, Train Loss: 0.1471, Val Loss: 0.2023
# Epoch 3/30, Train Loss: 0.1479, Val Loss: 0.2007
# Epoch 4/30, Train Loss: 0.2565, Val Loss: 0.2042
# Epoch 5/30, Train Loss: 0.1473, Val Loss: 0.2015
# Epoch 5/30, Train Loss: 0.1473, Val Loss: 0.2015
# Epoch 6/30, Train Loss: 0.1485, Val Loss: 0.2009
# Epoch 7/30, Train Loss: 0.1475, Val Loss: 0.2024
# Epoch 8/30, Train Loss: 0.1799, Val Loss: 0.2014
# Epoch 9/30, Train Loss: 0.1581, Val Loss: 0.2018
# Epoch 10/30, Train Loss: 0.1489, Val Loss: 0.2035
# Epoch 11/30, Train Loss: 0.1488, Val Loss: 0.2061
# Epoch 12/30, Train Loss: 0.1474, Val Loss: 0.2025
# Epoch 13/30, Train Loss: 0.1473, Val Loss: 0.2007
# Epoch 14/30, Train Loss: 0.1474, Val Loss: 0.2011
# Epoch 15/30, Train Loss: 0.1625, Val Loss: 0.2027
# Epoch 16/30, Train Loss: 0.1739, Val Loss: 0.2065
# Epoch 17/30, Train Loss: 0.2083, Val Loss: 0.2026
# Epoch 18/30, Train Loss: 0.2822, Val Loss: 0.2020
# Epoch 19/30, Train Loss: 0.1964, Val Loss: 0.2014
# Epoch 20/30, Train Loss: 0.1537, Val Loss: 0.2033
# Epoch 21/30, Train Loss: 0.1513, Val Loss: 0.2022
# Epoch 22/30, Train Loss: 0.1475, Val Loss: 0.2005
# Epoch 23/30, Train Loss: 0.1847, Val Loss: 0.2019
# Epoch 24/30, Train Loss: 0.1477, Val Loss: 0.2014
# Epoch 25/30, Train Loss: 0.1580, Val Loss: 0.2013
# Epoch 26/30, Train Loss: 0.2927, Val Loss: 0.2018
# Epoch 27/30, Train Loss: 0.2068, Val Loss: 0.2035
# Epoch 28/30, Train Loss: 0.1487, Val Loss: 0.2028
# Epoch 29/30, Train Loss: 0.2096, Val Loss: 0.2029
# Epoch 30/30, Train Loss: 0.1637, Val Loss: 0.2015
#
# #### Normalized (lr:1e-3)
# Epoch 1/30, Train Loss: 0.1301, Val Loss: 0.2252
# Epoch 2/30, Train Loss: 0.1085, Val Loss: 0.2124
# Epoch 3/30, Train Loss: 0.0955, Val Loss: 0.2141
# Epoch 4/30, Train Loss: 0.0878, Val Loss: 0.2220
# Epoch 5/30, Train Loss: 0.0809, Val Loss: 0.2198
# Epoch 6/30, Train Loss: 0.0728, Val Loss: 0.2421
# Epoch 7/30, Train Loss: 0.0674, Val Loss: 0.2345
# Epoch 8/30, Train Loss: 0.0610, Val Loss: 0.2260
# Epoch 9/30, Train Loss: 0.0566, Val Loss: 0.2249
# Epoch 10/30, Train Loss: 0.0518, Val Loss: 0.2360
# Epoch 11/30, Train Loss: 0.0471, Val Loss: 0.2445
# Epoch 12/30, Train Loss: 0.0439, Val Loss: 0.2571
# Epoch 13/30, Train Loss: 0.0409, Val Loss: 0.2535
# Epoch 14/30, Train Loss: 0.0375, Val Loss: 0.2318
# Epoch 15/30, Train Loss: 0.0339, Val Loss: 0.2399
# Epoch 16/30, Train Loss: 0.0320, Val Loss: 0.2503
# Epoch 17/30, Train Loss: 0.0308, Val Loss: 0.2347
# Epoch 18/30, Train Loss: 0.0294, Val Loss: 0.2469
# Epoch 19/30, Train Loss: 0.0280, Val Loss: 0.2486
# Epoch 20/30, Train Loss: 0.0264, Val Loss: 0.2466
# Epoch 21/30, Train Loss: 0.0238, Val Loss: 0.2462
# Epoch 22/30, Train Loss: 0.0225, Val Loss: 0.2409
# Epoch 23/30, Train Loss: 0.0218, Val Loss: 0.2441
# Epoch 24/30, Train Loss: 0.0211, Val Loss: 0.2405
# Epoch 25/30, Train Loss: 0.0197, Val Loss: 0.2694
# Epoch 26/30, Train Loss: 0.0204, Val Loss: 0.2484
# Epoch 27/30, Train Loss: 0.0183, Val Loss: 0.2595
# Epoch 28/30, Train Loss: 0.0182, Val Loss: 0.2545
# Epoch 29/30, Train Loss: 0.0186, Val Loss: 0.2484
# Epoch 30/30, Train Loss: 0.0172, Val Loss: 0.2573
#
# ### Text Only
# ##### Normalized (lr:1e-2)
# Epoch 1/30, Train Loss: 0.1679, Val Loss: 0.2008
# Epoch 2/30, Train Loss: 0.1479, Val Loss: 0.2022
# Epoch 3/30, Train Loss: 0.1479, Val Loss: 0.2018
# Epoch 4/30, Train Loss: 0.1475, Val Loss: 0.2023
# Epoch 5/30, Train Loss: 0.1475, Val Loss: 0.2011
# Epoch 6/30, Train Loss: 0.1532, Val Loss: 0.2013
# Epoch 7/30, Train Loss: 0.1813, Val Loss: 0.2017
# Epoch 8/30, Train Loss: 0.1591, Val Loss: 0.2038
# Epoch 9/30, Train Loss: 0.1479, Val Loss: 0.2013
# Epoch 10/30, Train Loss: 0.1503, Val Loss: 0.2038
# Epoch 11/30, Train Loss: 0.1932, Val Loss: 0.2010
# Epoch 12/30, Train Loss: 0.1477, Val Loss: 0.2014
# Epoch 13/30, Train Loss: 0.1571, Val Loss: 0.2007
# Epoch 14/30, Train Loss: 0.1472, Val Loss: 0.2014
# Epoch 15/30, Train Loss: 0.8441, Val Loss: 0.2038
# Epoch 16/30, Train Loss: 0.1487, Val Loss: 0.2023
# Epoch 17/30, Train Loss: 0.1475, Val Loss: 0.2043
# Epoch 18/30, Train Loss: 0.1642, Val Loss: 0.2012
# Epoch 18/30, Train Loss: 0.1642, Val Loss: 0.2012
# Epoch 19/30, Train Loss: 0.1474, Val Loss: 0.2056
# Epoch 20/30, Train Loss: 2.1051, Val Loss: 0.2050
# Epoch 21/30, Train Loss: 0.1479, Val Loss: 0.2020
# Epoch 22/30, Train Loss: 0.1482, Val Loss: 0.2008
# Epoch 23/30, Train Loss: 0.1592, Val Loss: 0.2039
# Epoch 24/30, Train Loss: 0.3377, Val Loss: 0.2011
# Epoch 25/30, Train Loss: 0.1577, Val Loss: 0.2019
# Epoch 26/30, Train Loss: 0.1549, Val Loss: 0.2008
# Epoch 27/30, Train Loss: 0.2816, Val Loss: 0.2018
# Epoch 28/30, Train Loss: 0.2191, Val Loss: 0.2139
# Epoch 29/30, Train Loss: 0.3372, Val Loss: 0.2023
# Epoch 30/30, Train Loss: 0.2830, Val Loss: 0.2023
#
# ##### Normalized (lr:1e-3)
# Epoch 1/30, Train Loss: 0.1506, Val Loss: 0.2073
# Epoch 2/30, Train Loss: 0.1436, Val Loss: 0.2054
# Epoch 3/30, Train Loss: 0.1421, Val Loss: 0.2054
# Epoch 4/30, Train Loss: 0.1409, Val Loss: 0.2195
# Epoch 5/30, Train Loss: 0.1400, Val Loss: 0.2060
# Epoch 6/30, Train Loss: 0.1391, Val Loss: 0.2094
# Epoch 7/30, Train Loss: 0.1377, Val Loss: 0.2122
# Epoch 8/30, Train Loss: 0.1362, Val Loss: 0.2190
# Epoch 9/30, Train Loss: 0.1353, Val Loss: 0.2142
# Epoch 10/30, Train Loss: 0.1338, Val Loss: 0.2149
# Epoch 11/30, Train Loss: 0.1329, Val Loss: 0.2142
# Epoch 12/30, Train Loss: 0.1312, Val Loss: 0.2118
# Epoch 13/30, Train Loss: 0.1296, Val Loss: 0.2321
# Epoch 14/30, Train Loss: 0.1272, Val Loss: 0.2192
# Epoch 15/30, Train Loss: 0.1265, Val Loss: 0.2251
# Epoch 16/30, Train Loss: 0.1252, Val Loss: 0.2189
# Epoch 17/30, Train Loss: 0.1226, Val Loss: 0.2190
# Epoch 18/30, Train Loss: 0.1201, Val Loss: 0.2226
# Epoch 19/30, Train Loss: 0.1191, Val Loss: 0.2281
# Epoch 20/30, Train Loss: 0.1165, Val Loss: 0.2309
# Epoch 21/30, Train Loss: 0.1140, Val Loss: 0.2299
# Epoch 22/30, Train Loss: 0.1128, Val Loss: 0.2374
# Epoch 23/30, Train Loss: 0.1112, Val Loss: 0.2384
# Epoch 24/30, Train Loss: 0.1097, Val Loss: 0.2272
# Epoch 25/30, Train Loss: 0.1079, Val Loss: 0.2361
# Epoch 26/30, Train Loss: 0.1067, Val Loss: 0.2278
# Epoch 27/30, Train Loss: 0.1057, Val Loss: 0.2335
# Epoch 28/30, Train Loss: 0.1035, Val Loss: 0.2269
# Epoch 29/30, Train Loss: 0.1026, Val Loss: 0.2303
# Epoch 30/30, Train Loss: 0.1014, Val Loss: 0.2318
#
#
# ### Audio Only
# #### Normalized (lr:1e-2)
# Epoch 1/30, Train Loss: 0.1517, Val Loss: 0.2029
# Epoch 2/30, Train Loss: 0.1501, Val Loss: 0.2022
# Epoch 3/30, Train Loss: 0.1509, Val Loss: 0.2055
# Epoch 4/30, Train Loss: 0.1476, Val Loss: 0.2054
# Epoch 5/30, Train Loss: 0.1478, Val Loss: 0.2026
# Epoch 6/30, Train Loss: 0.1578, Val Loss: 0.2037
# Epoch 7/30, Train Loss: 0.1474, Val Loss: 0.2006
# Epoch 8/30, Train Loss: 0.1505, Val Loss: 0.2066
# Epoch 9/30, Train Loss: 0.1557, Val Loss: 0.2025
# Epoch 10/30, Train Loss: 0.1482, Val Loss: 0.2015
# Epoch 11/30, Train Loss: 0.1592, Val Loss: 0.2029
# Epoch 12/30, Train Loss: 0.1535, Val Loss: 0.2026
# Epoch 13/30, Train Loss: 0.1508, Val Loss: 0.2047
# Epoch 14/30, Train Loss: 0.1548, Val Loss: 0.2012
# Epoch 15/30, Train Loss: 0.1475, Val Loss: 0.2018
# Epoch 16/30, Train Loss: 0.1475, Val Loss: 0.2073
# Epoch 17/30, Train Loss: 0.1486, Val Loss: 0.2026
# Epoch 18/30, Train Loss: 0.1535, Val Loss: 0.2008
# Epoch 19/30, Train Loss: 0.1559, Val Loss: 0.2007
# Epoch 20/30, Train Loss: 0.1784, Val Loss: 0.2017
# Epoch 21/30, Train Loss: 0.2019, Val Loss: 0.2010
# Epoch 22/30, Train Loss: 0.1598, Val Loss: 0.2044
# Epoch 23/30, Train Loss: 0.1477, Val Loss: 0.2011
# Epoch 24/30, Train Loss: 0.1554, Val Loss: 0.2023
# Epoch 25/30, Train Loss: 0.1727, Val Loss: 0.2026
# Epoch 26/30, Train Loss: 0.1500, Val Loss: 0.2051
# Epoch 27/30, Train Loss: 0.1484, Val Loss: 0.2025
# Epoch 28/30, Train Loss: 0.1501, Val Loss: 0.2035
# Epoch 29/30, Train Loss: 0.1473, Val Loss: 0.2021
# Epoch 30/30, Train Loss: 0.1489, Val Loss: 0.2016
#
# #### Normalized (lr:1e-3)
# Epoch 1/30, Train Loss: 0.1281, Val Loss: 0.2198
# Epoch 2/30, Train Loss: 0.1060, Val Loss: 0.2127
# Epoch 3/30, Train Loss: 0.0948, Val Loss: 0.2190
# Epoch 4/30, Train Loss: 0.0851, Val Loss: 0.2186
# Epoch 5/30, Train Loss: 0.0781, Val Loss: 0.2272
# Epoch 6/30, Train Loss: 0.0703, Val Loss: 0.2338
# Epoch 7/30, Train Loss: 0.0633, Val Loss: 0.2228
# Epoch 8/30, Train Loss: 0.0582, Val Loss: 0.2292
# Epoch 9/30, Train Loss: 0.0535, Val Loss: 0.2337
# Epoch 10/30, Train Loss: 0.0482, Val Loss: 0.2433
# Epoch 11/30, Train Loss: 0.0450, Val Loss: 0.2438
# Epoch 12/30, Train Loss: 0.0417, Val Loss: 0.2490
# Epoch 13/30, Train Loss: 0.0382, Val Loss: 0.2361
# Epoch 14/30, Train Loss: 0.0362, Val Loss: 0.2457
# Epoch 15/30, Train Loss: 0.0331, Val Loss: 0.2392
# Epoch 16/30, Train Loss: 0.0325, Val Loss: 0.2470
# Epoch 17/30, Train Loss: 0.0312, Val Loss: 0.2483
# Epoch 18/30, Train Loss: 0.0278, Val Loss: 0.2373
# Epoch 19/30, Train Loss: 0.0266, Val Loss: 0.2482
# Epoch 20/30, Train Loss: 0.0264, Val Loss: 0.2474
# Epoch 21/30, Train Loss: 0.0261, Val Loss: 0.2404
# Epoch 22/30, Train Loss: 0.0246, Val Loss: 0.2454
# Epoch 23/30, Train Loss: 0.0238, Val Loss: 0.2430
# Epoch 24/30, Train Loss: 0.0230, Val Loss: 0.2382
# Epoch 25/30, Train Loss: 0.0219, Val Loss: 0.2469
# Epoch 26/30, Train Loss: 0.0209, Val Loss: 0.2423
# Epoch 27/30, Train Loss: 0.0213, Val Loss: 0.2301
# Epoch 28/30, Train Loss: 0.0205, Val Loss: 0.2438
# Epoch 29/30, Train Loss: 0.0198, Val Loss: 0.2465
# Epoch 30/30, Train Loss: 0.0195, Val Loss: 0.2417

# %% [markdown]
# ## K-Fold Cross-Validation
# TEST: ['ExtraEmily', 'Keeoh', 'NateHill', 'RachtaZ', 'Swiftor', 'Scarra', 'L3WG', 'BobbyPoffGaming', 'EsfandTV', 'nl_Kripp', 'Punz', 'ImperialHal__', 'robcdee', 'TobiasFate', 'caseoh_', 'Ray__C', 'Flight23white', 'Loeya', 'Gosu']
#
# ### Fold 1
# Epoch 1/20, Train Loss: 1.2582, Val Loss: 1.5045
# Epoch 2/20, Train Loss: 1.0328, Val Loss: 1.6318
# Epoch 3/20, Train Loss: 0.9895, Val Loss: 1.5056
# Epoch 4/20, Train Loss: 0.9455, Val Loss: 1.7854
# Epoch 5/20, Train Loss: 0.9377, Val Loss: 1.6029
# Epoch 6/20, Train Loss: 0.9086, Val Loss: 1.5601
# Epoch 7/20, Train Loss: 0.9289, Val Loss: 1.5506
# Epoch 8/20, Train Loss: 0.8909, Val Loss: 1.4857
# Epoch 9/20, Train Loss: 0.8956, Val Loss: 1.5581
# Epoch 10/20, Train Loss: 0.8871, Val Loss: 1.5085
# Epoch 11/20, Train Loss: 0.8912, Val Loss: 1.5995
# Epoch 12/20, Train Loss: 0.8734, Val Loss: 1.5892
# Epoch 13/20, Train Loss: 0.8626, Val Loss: 1.5053
# Epoch 14/20, Train Loss: 0.8725, Val Loss: 1.5733
# Epoch 15/20, Train Loss: 1.1939, Val Loss: 1.5150
# Epoch 16/20, Train Loss: 0.9383, Val Loss: 1.7949
# Epoch 17/20, Train Loss: 0.8881, Val Loss: 1.6351
# Epoch 18/20, Train Loss: 1.0053, Val Loss: 1.5108
# Epoch 19/20, Train Loss: 1.1238, Val Loss: 1.4858
# Epoch 20/20, Train Loss: 1.0373, Val Loss: 1.4507
#
# ### Fold 2
# Epoch 1/20, Train Loss: 1.3767, Val Loss: 1.2962
# Epoch 2/20, Train Loss: 1.1293, Val Loss: 1.1896
# Epoch 3/20, Train Loss: 0.9589, Val Loss: 1.2130
# Epoch 4/20, Train Loss: 0.9051, Val Loss: 0.9662
# Epoch 5/20, Train Loss: 0.8787, Val Loss: 1.2297
# Epoch 6/20, Train Loss: 0.8677, Val Loss: 1.0727
# Epoch 7/20, Train Loss: 0.8801, Val Loss: 1.3771
# Epoch 8/20, Train Loss: 0.8344, Val Loss: 1.1443
# Epoch 9/20, Train Loss: 0.8535, Val Loss: 0.9646
# Epoch 10/20, Train Loss: 0.8202, Val Loss: 1.0139
# Epoch 11/20, Train Loss: 0.7912, Val Loss: 1.0715
# Epoch 12/20, Train Loss: 0.8743, Val Loss: 1.4325
# Epoch 13/20, Train Loss: 0.7780, Val Loss: 1.5448
# Epoch 14/20, Train Loss: 0.7925, Val Loss: 1.1823
# Epoch 15/20, Train Loss: 0.8916, Val Loss: 1.6187
# Epoch 16/20, Train Loss: 0.8282, Val Loss: 1.0194
# Epoch 17/20, Train Loss: 0.8527, Val Loss: 1.1248
# Epoch 18/20, Train Loss: 0.8751, Val Loss: 1.6150
# Epoch 19/20, Train Loss: 0.8376, Val Loss: 1.1861
# Epoch 20/20, Train Loss: 0.8656, Val Loss: 0.8918
#
# ### Fold 3
# Epoch 1/20, Train Loss: 1.5969, Val Loss: 1.3200
# Epoch 2/20, Train Loss: 1.2438, Val Loss: 0.7441
# Epoch 3/20, Train Loss: 1.2261, Val Loss: 1.3310
# Epoch 4/20, Train Loss: 1.0780, Val Loss: 0.7831
# Epoch 5/20, Train Loss: 1.0384, Val Loss: 0.7589
# Epoch 6/20, Train Loss: 0.9685, Val Loss: 0.7493
# Epoch 7/20, Train Loss: 0.9725, Val Loss: 0.8649
# Epoch 8/20, Train Loss: 0.9438, Val Loss: 0.8241
# Epoch 9/20, Train Loss: 0.9518, Val Loss: 0.7147
# Epoch 10/20, Train Loss: 1.0595, Val Loss: 0.8095
# Epoch 11/20, Train Loss: 1.0596, Val Loss: 1.1293
# Epoch 12/20, Train Loss: 1.0062, Val Loss: 0.9302
# Epoch 13/20, Train Loss: 1.0003, Val Loss: 0.7805
# Epoch 14/20, Train Loss: 1.0286, Val Loss: 0.7028
# Epoch 15/20, Train Loss: 1.0295, Val Loss: 1.4675
# Epoch 16/20, Train Loss: 0.9285, Val Loss: 0.8550
# Epoch 17/20, Train Loss: 1.1176, Val Loss: 0.7951
# Epoch 18/20, Train Loss: 1.0814, Val Loss: 0.9501
# Epoch 19/20, Train Loss: 1.1908, Val Loss: 0.7270
# Epoch 20/20, Train Loss: 1.1751, Val Loss: 0.7182
#
# ### Fold 4
# Epoch 1/20, Train Loss: 1.1902, Val Loss: 1.5770
# Epoch 2/20, Train Loss: 0.9274, Val Loss: 1.5831
# Epoch 3/20, Train Loss: 0.7848, Val Loss: 1.8038
# Epoch 4/20, Train Loss: 0.7290, Val Loss: 1.6635
# Epoch 5/20, Train Loss: 0.7088, Val Loss: 1.6007
# Epoch 6/20, Train Loss: 0.6642, Val Loss: 1.7237
# Epoch 7/20, Train Loss: 0.6560, Val Loss: 1.7175
# Epoch 8/20, Train Loss: 0.6648, Val Loss: 1.6943
# Epoch 9/20, Train Loss: 0.6571, Val Loss: 1.6098
# Epoch 10/20, Train Loss: 0.6286, Val Loss: 1.8319
# Epoch 11/20, Train Loss: 0.6019, Val Loss: 1.6175
# Epoch 12/20, Train Loss: 0.5775, Val Loss: 1.6182
# Epoch 13/20, Train Loss: 0.6447, Val Loss: 1.5893
# Epoch 14/20, Train Loss: 0.6069, Val Loss: 1.5692
# Epoch 15/20, Train Loss: 0.5352, Val Loss: 1.5681
# Epoch 16/20, Train Loss: 0.5753, Val Loss: 1.7113
# Epoch 17/20, Train Loss: 0.5503, Val Loss: 1.5726
# Epoch 18/20, Train Loss: 0.5603, Val Loss: 1.7408
# Epoch 19/20, Train Loss: 0.5446, Val Loss: 1.9078
# Epoch 20/20, Train Loss: 0.5766, Val Loss: 1.6481

# %% [markdown]
# # Testing Regression

# %% [markdown]
# ### 80-20 Split
# MSE: 2.5718
# MAE: 0.7689
# R² Score: -0.0087
#
# ### 70-30 Split
# Validation MSE Loss: 1.0704
# Pred: 5.705, Target: 6.456
# Pred: 5.984, Target: 5.534
# Pred: 5.787, Target: 5.343
# Pred: 5.812, Target: 6.264
# Pred: 5.920, Target: 6.500
#
# ### 60-40 Split
# MSE: 2.3743
# MAE: 0.7175
# R² Score: -0.0455
#
# ### Audio Normalized
# Validation MSE Loss: 0.7173
# Pred: 6.163, Target: 5.343
# Pred: 5.628, Target: 6.750
# Pred: 6.232, Target: 5.343
# Pred: 6.362, Target: 6.456
# Pred: 5.774, Target: 5.596
#
# ### Text Normalized
# Validation MSE Loss: 0.9462
# Pred: 6.005, Target: 5.596
# Pred: 5.745, Target: 6.571
# Pred: 5.986, Target: 6.750
# Pred: 5.935, Target: 6.210
# Pred: 6.132, Target: 6.210

# %% [markdown]
# # Training Classification

# %% [markdown]
# ### 70-30 Split
# TEST: ['Philza', 'Nightblue3', 'LIRIK', 'ScreaM', 'PaymoneyWubby', 'fuslie', 'starsmitten', 'LVNDMARK', 'Lord_Kebun', 'DrLupo', 'Keeoh', 'PENTA', 'Ray__C', 'Zoomaa', 'NickEh30', 'Emongg', 'BobRoss', 'SwaggerSouls', 'Aydan', 'Pestily', 'BobbyPoffGaming', 'Sykkuno', 'L3WG', 'Valkyrae', 'summit1g', 'PontiacMadeDDG', 'moistcr1tikal', 'Punz', 'GoldGlove', 'iiTzTimmy', 'MurderCrumpet', 'iddqd', 'ImperialHal__', 'stableronaldo', 'BarbarousKing', 'KidShadoe', 'Insym', 'yourragegaming', 'BadBoyHalo', 'SypherPK', 'Nadeshot', 'Gosu', 'CohhCarnage', 'RachtaZ', 'RTGame', 'MOONMOON', 'capturesca', 'x2Twins', 'scump', 'aceu', 'peterpark', 'Shotz', 'CDawgVA', 'kyliebitkin', 'Northernlion']
# Epoch 1/30
#   Train Loss: 1.1006, Train Acc: 34.10%
#   Val   Loss: 1.0983, Val   Acc: 35.17%
# Epoch 2/30
#   Train Loss: 1.0989, Train Acc: 34.56%
#   Val   Loss: 1.0981, Val   Acc: 35.17%
# Epoch 3/30
#   Train Loss: 1.0989, Train Acc: 33.38%
#   Val   Loss: 1.0984, Val   Acc: 35.17%
# Epoch 4/30
#   Train Loss: 1.0988, Train Acc: 34.28%
#   Val   Loss: 1.0980, Val   Acc: 35.17%
# Epoch 5/30
#   Train Loss: 1.0989, Train Acc: 33.99%
#   Val   Loss: 1.0995, Val   Acc: 35.17%
# Epoch 6/30
#   Train Loss: 1.0990, Train Acc: 34.31%
#   Val   Loss: 1.1004, Val   Acc: 32.16%
# Epoch 7/30
#   Train Loss: 1.0986, Train Acc: 34.09%
#   Val   Loss: 1.1004, Val   Acc: 32.16%
# Epoch 8/30
#   Train Loss: 1.0995, Train Acc: 33.68%
#   Val   Loss: 1.0986, Val   Acc: 35.17%
# Epoch 9/30
#   Train Loss: 1.0987, Train Acc: 33.92%
#   Val   Loss: 1.0993, Val   Acc: 32.16%
# Epoch 10/30
#   Train Loss: 1.0987, Train Acc: 34.01%
#   Val   Loss: 1.0984, Val   Acc: 35.17%
# Epoch 11/30
#   Train Loss: 1.0990, Train Acc: 34.36%
#   Val   Loss: 1.0980, Val   Acc: 35.17%
# Epoch 12/30
#   Train Loss: 1.0988, Train Acc: 34.54%
#   Val   Loss: 1.0993, Val   Acc: 32.16%
# Epoch 13/30
#   Train Loss: 1.0989, Train Acc: 33.87%
#   Val   Loss: 1.0994, Val   Acc: 35.17%
# Epoch 14/30
#   Train Loss: 1.0987, Train Acc: 33.95%
#   Val   Loss: 1.0984, Val   Acc: 35.17%
# Epoch 15/30
#   Train Loss: 1.0990, Train Acc: 34.21%
#   Val   Loss: 1.0997, Val   Acc: 35.17%
# Epoch 16/30
#   Train Loss: 1.0989, Train Acc: 34.02%
#   Val   Loss: 1.0993, Val   Acc: 32.16%
# Epoch 17/30
#   Train Loss: 1.0991, Train Acc: 34.21%
#   Val   Loss: 1.0996, Val   Acc: 35.17%
# Epoch 18/30
#   Train Loss: 1.0988, Train Acc: 34.10%
#   Val   Loss: 1.0989, Val   Acc: 32.16%
# Epoch 19/30
#   Train Loss: 1.0988, Train Acc: 34.51%
#   Val   Loss: 1.0989, Val   Acc: 32.16%
# Epoch 20/30
#   Train Loss: 1.0987, Train Acc: 33.76%
#   Val   Loss: 1.0989, Val   Acc: 32.67%
# Epoch 21/30
#   Train Loss: 1.0987, Train Acc: 34.24%
#   Val   Loss: 1.0980, Val   Acc: 35.17%
# Epoch 22/30
#   Train Loss: 1.0986, Train Acc: 34.80%
#   Val   Loss: 1.1018, Val   Acc: 35.17%
# Epoch 23/30
#   Train Loss: 1.0989, Train Acc: 34.15%
#   Val   Loss: 1.0980, Val   Acc: 35.17%
# Epoch 24/30
#   Train Loss: 1.0990, Train Acc: 34.11%
#   Val   Loss: 1.1000, Val   Acc: 35.17%
# Epoch 25/30
#   Train Loss: 1.0990, Train Acc: 34.50%
#   Val   Loss: 1.0998, Val   Acc: 32.16%
# Epoch 26/30
#   Train Loss: 1.0990, Train Acc: 33.89%
#   Val   Loss: 1.1028, Val   Acc: 32.16%
# Epoch 27/30
#   Train Loss: 1.0990, Train Acc: 34.00%
#   Val   Loss: 1.0993, Val   Acc: 35.17%
# Epoch 28/30
#   Train Loss: 1.0988, Train Acc: 33.97%
#   Val   Loss: 1.0980, Val   Acc: 35.17%
# Epoch 29/30
#   Train Loss: 1.0991, Train Acc: 34.01%
#   Val   Loss: 1.0979, Val   Acc: 35.17%
# Epoch 30/30
#   Train Loss: 1.0985, Train Acc: 34.53%
#   Val   Loss: 1.0978, Val   Acc: 35.17%
# Model saved to models/streamer_class_model_t70.pth
#
# #### Normalized
# Epoch 1/30
#   Train Loss: 1.1052, Train Acc: 34.32%
#   Val   Loss: 1.0977, Val   Acc: 34.88%
# Epoch 2/30
#   Train Loss: 1.0990, Train Acc: 34.71%
#   Val   Loss: 1.0978, Val   Acc: 34.88%
# Epoch 3/30
#   Train Loss: 1.0989, Train Acc: 34.04%
#   Val   Loss: 1.0988, Val   Acc: 30.97%
# Epoch 4/30
#   Train Loss: 1.0992, Train Acc: 34.07%
#   Val   Loss: 1.0973, Val   Acc: 34.16%
# Epoch 5/30
#   Train Loss: 1.0990, Train Acc: 34.03%
#   Val   Loss: 1.0980, Val   Acc: 34.88%
# Epoch 6/30
#   Train Loss: 1.0989, Train Acc: 33.74%
#   Val   Loss: 1.0984, Val   Acc: 34.88%
# Epoch 7/30
#   Train Loss: 1.0992, Train Acc: 33.65%
#   Val   Loss: 1.0986, Val   Acc: 34.88%
# Epoch 8/30
#   Train Loss: 1.0992, Train Acc: 33.76%
#   Val   Loss: 1.0983, Val   Acc: 34.88%
# Epoch 9/30
#   Train Loss: 1.0990, Train Acc: 34.07%
#   Val   Loss: 1.0974, Val   Acc: 34.88%
# Epoch 10/30
#   Train Loss: 1.0992, Train Acc: 33.74%
#   Val   Loss: 1.0980, Val   Acc: 34.88%
# Epoch 11/30
#   Train Loss: 1.0992, Train Acc: 34.22%
#   Val   Loss: 1.0979, Val   Acc: 34.88%
# Epoch 12/30
#   Train Loss: 1.0991, Train Acc: 34.01%
#   Val   Loss: 1.0985, Val   Acc: 34.88%
# Epoch 13/30
#   Train Loss: 1.0991, Train Acc: 34.20%
#   Val   Loss: 1.0993, Val   Acc: 34.88%
# Epoch 14/30
#   Train Loss: 1.0995, Train Acc: 33.63%
#   Val   Loss: 1.0984, Val   Acc: 34.88%
# Epoch 15/30
#   Train Loss: 1.0990, Train Acc: 33.98%
#   Val   Loss: 1.0986, Val   Acc: 34.16%
# Epoch 16/30
#   Train Loss: 1.0991, Train Acc: 33.97%
#   Val   Loss: 1.0982, Val   Acc: 34.16%
# Epoch 17/30
#   Train Loss: 1.0994, Train Acc: 33.73%
#   Val   Loss: 1.0973, Val   Acc: 34.88%
# Epoch 18/30
#   Train Loss: 1.0991, Train Acc: 34.07%
#   Val   Loss: 1.0972, Val   Acc: 34.88%
# Epoch 19/30
#   Train Loss: 1.0990, Train Acc: 33.93%
#   Val   Loss: 1.0975, Val   Acc: 34.88%
# Epoch 20/30
#   Train Loss: 1.0988, Train Acc: 34.04%
#   Val   Loss: 1.0977, Val   Acc: 34.88%
# Epoch 21/30
#   Train Loss: 1.0992, Train Acc: 33.84%
#   Val   Loss: 1.0987, Val   Acc: 34.88%
# Epoch 22/30
#   Train Loss: 1.0991, Train Acc: 33.84%
#   Val   Loss: 1.0979, Val   Acc: 34.88%
# Epoch 23/30
#   Train Loss: 1.0988, Train Acc: 34.43%
#   Val   Loss: 1.0980, Val   Acc: 34.16%
# Epoch 24/30
#   Train Loss: 1.0988, Train Acc: 34.59%
#   Val   Loss: 1.0978, Val   Acc: 34.88%
# Epoch 25/30
#   Train Loss: 1.0988, Train Acc: 34.73%
#   Val   Loss: 1.0975, Val   Acc: 34.88%
# Epoch 26/30
#   Train Loss: 1.0992, Train Acc: 33.96%
#   Val   Loss: 1.0986, Val   Acc: 34.16%
# Epoch 27/30
#   Train Loss: 1.0992, Train Acc: 33.91%
#   Val   Loss: 1.0979, Val   Acc: 34.88%
# Epoch 28/30
#   Train Loss: 1.0990, Train Acc: 33.80%
#   Val   Loss: 1.0993, Val   Acc: 34.88%
# Epoch 29/30
#   Train Loss: 1.0991, Train Acc: 33.75%
#   Val   Loss: 1.0975, Val   Acc: 34.88%
# Epoch 30/30
#   Train Loss: 1.0988, Train Acc: 34.32%
#   Val   Loss: 1.0976, Val   Acc: 34.16%
#
# ### Text Only
# Epoch 1/30
#   Train Loss: 1.0999, Train Acc: 33.83%
#   Val   Loss: 1.0991, Val   Acc: 34.34%
# Epoch 2/30
#   Train Loss: 1.0991, Train Acc: 34.50%
#   Val   Loss: 1.0980, Val   Acc: 34.34%
# Epoch 3/30
#   Train Loss: 1.0991, Train Acc: 33.95%
#   Val   Loss: 1.0994, Val   Acc: 34.34%
# Epoch 4/30
#   Train Loss: 1.0990, Train Acc: 34.09%
#   Val   Loss: 1.0991, Val   Acc: 34.34%
# Epoch 5/30
#   Train Loss: 1.0991, Train Acc: 33.85%
#   Val   Loss: 1.0977, Val   Acc: 34.34%
# Epoch 6/30
#   Train Loss: 1.0987, Train Acc: 34.51%
#   Val   Loss: 1.0997, Val   Acc: 34.34%
# Epoch 7/30
#   Train Loss: 1.0988, Train Acc: 33.92%
#   Val   Loss: 1.0978, Val   Acc: 34.38%
# Epoch 8/30
#   Train Loss: 1.0990, Train Acc: 34.02%
#   Val   Loss: 1.0979, Val   Acc: 34.34%
# Epoch 9/30
#   Train Loss: 1.0989, Train Acc: 34.21%
#   Val   Loss: 1.0976, Val   Acc: 34.38%
# Epoch 10/30
#   Train Loss: 1.0994, Train Acc: 33.74%
#   Val   Loss: 1.0978, Val   Acc: 34.34%
# Epoch 11/30
#   Train Loss: 1.0990, Train Acc: 34.21%
#   Val   Loss: 1.0978, Val   Acc: 34.38%
# Epoch 12/30
#   Train Loss: 1.0989, Train Acc: 33.77%
#   Val   Loss: 1.0982, Val   Acc: 34.34%
# Epoch 13/30
#   Train Loss: 1.0989, Train Acc: 33.94%
#   Val   Loss: 1.0977, Val   Acc: 34.38%
# Epoch 14/30
#   Train Loss: 1.0989, Train Acc: 34.33%
#   Val   Loss: 1.1001, Val   Acc: 34.34%
# Epoch 15/30
#   Train Loss: 1.0991, Train Acc: 33.80%
#   Val   Loss: 1.0978, Val   Acc: 34.34%
# Epoch 16/30
#   Train Loss: 1.0985, Train Acc: 34.19%
#   Val   Loss: 1.0978, Val   Acc: 34.34%
# Epoch 17/30
#   Train Loss: 1.0991, Train Acc: 33.98%
#   Val   Loss: 1.0990, Val   Acc: 34.34%
# Epoch 18/30
#   Train Loss: 1.0990, Train Acc: 34.28%
#   Val   Loss: 1.0979, Val   Acc: 34.34%
# Epoch 19/30
#   Train Loss: 1.0990, Train Acc: 33.88%
#   Val   Loss: 1.1020, Val   Acc: 34.34%
# Epoch 20/30
#   Train Loss: 1.0990, Train Acc: 34.35%
#   Val   Loss: 1.0976, Val   Acc: 34.34%
# Epoch 21/30
#   Train Loss: 1.0991, Train Acc: 33.77%
#   Val   Loss: 1.0993, Val   Acc: 31.28%
# Epoch 22/30
#   Train Loss: 1.0990, Train Acc: 33.85%
#   Val   Loss: 1.0991, Val   Acc: 34.34%
# Epoch 23/30
#   Train Loss: 1.0991, Train Acc: 34.37%
#   Val   Loss: 1.0980, Val   Acc: 34.34%
# Epoch 24/30
#   Train Loss: 1.0988, Train Acc: 34.02%
#   Val   Loss: 1.0989, Val   Acc: 34.34%
# Epoch 25/30
#   Train Loss: 1.0992, Train Acc: 33.94%
#   Val   Loss: 1.0984, Val   Acc: 34.34%
# Epoch 26/30
#   Train Loss: 1.0987, Train Acc: 34.64%
#   Val   Loss: 1.1007, Val   Acc: 34.34%
# Epoch 27/30
#   Train Loss: 1.0988, Train Acc: 34.37%
#   Val   Loss: 1.0996, Val   Acc: 31.28%
# Epoch 28/30
#   Train Loss: 1.0989, Train Acc: 33.92%
#   Val   Loss: 1.0986, Val   Acc: 34.34%
# Epoch 29/30
#   Train Loss: 1.0989, Train Acc: 34.23%
#   Val   Loss: 1.0980, Val   Acc: 34.34%
# Epoch 30/30
#   Train Loss: 1.0994, Train Acc: 33.95%
#   Val   Loss: 1.0982, Val   Acc: 34.34%
# #### Normalized
# Epoch 1/30
#   Train Loss: 1.1087, Train Acc: 34.29%
#   Val   Loss: 1.0993, Val   Acc: 34.20%
# Epoch 2/30
#   Train Loss: 1.0988, Train Acc: 34.52%
#   Val   Loss: 1.0985, Val   Acc: 33.21%
# Epoch 3/30
#   Train Loss: 1.0988, Train Acc: 34.42%
#   Val   Loss: 1.0994, Val   Acc: 33.21%
# Epoch 4/30
#   Train Loss: 1.0989, Train Acc: 34.11%
#   Val   Loss: 1.0985, Val   Acc: 34.20%
# Epoch 5/30
#   Train Loss: 1.0987, Train Acc: 34.41%
#   Val   Loss: 1.0992, Val   Acc: 34.20%
# Epoch 6/30
#   Train Loss: 1.0986, Train Acc: 34.61%
#   Val   Loss: 1.0989, Val   Acc: 33.21%
# Epoch 7/30
#   Train Loss: 1.0987, Train Acc: 34.20%
#   Val   Loss: 1.1001, Val   Acc: 34.20%
# Epoch 8/30
#   Train Loss: 1.0991, Train Acc: 33.73%
#   Val   Loss: 1.0998, Val   Acc: 33.21%
# Epoch 9/30
#   Train Loss: 1.0988, Train Acc: 34.22%
#   Val   Loss: 1.0986, Val   Acc: 34.20%
# Epoch 10/30
#   Train Loss: 1.0988, Train Acc: 34.26%
#   Val   Loss: 1.1029, Val   Acc: 34.20%
# Epoch 11/30
#   Train Loss: 1.0988, Train Acc: 34.10%
#   Val   Loss: 1.0996, Val   Acc: 34.20%
# Epoch 12/30
#   Train Loss: 1.0987, Train Acc: 34.61%
#   Val   Loss: 1.0997, Val   Acc: 32.58%
# Epoch 13/30
#   Train Loss: 1.0987, Train Acc: 33.79%
#   Val   Loss: 1.0997, Val   Acc: 33.21%
# Epoch 14/30
#   Train Loss: 1.0987, Train Acc: 34.36%
#   Val   Loss: 1.0991, Val   Acc: 34.20%
# Epoch 15/30
#   Train Loss: 1.0988, Train Acc: 34.07%
#   Val   Loss: 1.0990, Val   Acc: 33.21%
# Epoch 16/30
#   Train Loss: 1.0987, Train Acc: 34.12%
#   Val   Loss: 1.1002, Val   Acc: 34.20%
# Epoch 17/30
#   Train Loss: 1.0987, Train Acc: 34.21%
#   Val   Loss: 1.0998, Val   Acc: 34.20%
# Epoch 18/30
#   Train Loss: 1.0990, Train Acc: 34.47%
#   Val   Loss: 1.0986, Val   Acc: 34.20%
# Epoch 19/30
#   Train Loss: 1.0986, Train Acc: 34.17%
#   Val   Loss: 1.0989, Val   Acc: 34.20%
# Epoch 20/30
#   Train Loss: 1.0987, Train Acc: 34.22%
#   Val   Loss: 1.1003, Val   Acc: 34.20%
# Epoch 21/30
#   Train Loss: 1.0990, Train Acc: 33.95%
#   Val   Loss: 1.1007, Val   Acc: 34.20%
# Epoch 22/30
#   Train Loss: 1.0987, Train Acc: 34.34%
#   Val   Loss: 1.1004, Val   Acc: 34.20%
# Epoch 23/30
#   Train Loss: 1.0989, Train Acc: 34.49%
#   Val   Loss: 1.0988, Val   Acc: 34.20%
# Epoch 24/30
#   Train Loss: 1.0985, Train Acc: 34.30%
#   Val   Loss: 1.0994, Val   Acc: 34.20%
# Epoch 25/30
#   Train Loss: 1.0986, Train Acc: 33.84%
#   Val   Loss: 1.0997, Val   Acc: 34.20%
# Epoch 26/30
#   Train Loss: 1.0987, Train Acc: 34.02%
#   Val   Loss: 1.0991, Val   Acc: 34.20%
# Epoch 27/30
#   Train Loss: 1.0987, Train Acc: 34.21%
#   Val   Loss: 1.0988, Val   Acc: 34.20%
# Epoch 28/30
#   Train Loss: 1.0986, Train Acc: 34.27%
#   Val   Loss: 1.0988, Val   Acc: 34.20%
# Epoch 29/30
#   Train Loss: 1.0986, Train Acc: 34.43%
#   Val   Loss: 1.1022, Val   Acc: 34.20%
# Epoch 30/30
#   Train Loss: 1.0990, Train Acc: 34.37%
#   Val   Loss: 1.0994, Val   Acc: 34.20%
#
# ### Audio Only
# Epoch 1/30
#   Train Loss: 1.0957, Train Acc: 37.57%
#   Val   Loss: 1.1171, Val   Acc: 39.73%
# Epoch 2/30
#   Train Loss: 1.0688, Train Acc: 41.79%
#   Val   Loss: 1.0624, Val   Acc: 43.75%
# Epoch 3/30
#   Train Loss: 1.0528, Train Acc: 44.37%
#   Val   Loss: 1.0629, Val   Acc: 45.36%
# Epoch 4/30
#   Train Loss: 1.0389, Train Acc: 45.47%
#   Val   Loss: 1.0458, Val   Acc: 45.92%
# Epoch 5/30
#   Train Loss: 1.0222, Train Acc: 47.68%
#   Val   Loss: 1.0524, Val   Acc: 46.04%
# Epoch 6/30
#   Train Loss: 1.0117, Train Acc: 48.75%
#   Val   Loss: 1.0247, Val   Acc: 49.20%
# Epoch 7/30
#   Train Loss: 0.9981, Train Acc: 49.59%
#   Val   Loss: 1.3052, Val   Acc: 45.79%
# Epoch 8/30
#   Train Loss: 0.9914, Train Acc: 50.78%
#   Val   Loss: 1.0867, Val   Acc: 45.79%
# Epoch 9/30
#   Train Loss: 0.9756, Train Acc: 52.39%
#   Val   Loss: 1.0342, Val   Acc: 49.88%
# Epoch 10/30
#   Train Loss: 0.9616, Train Acc: 53.56%
#   Val   Loss: 1.0236, Val   Acc: 50.37%
# Epoch 11/30
#   Train Loss: 0.9525, Train Acc: 54.95%
#   Val   Loss: 1.0228, Val   Acc: 50.86%
# Epoch 12/30
#   Train Loss: 0.9442, Train Acc: 55.59%
#   Val   Loss: 1.0128, Val   Acc: 51.07%
# Epoch 13/30
#   Train Loss: 0.9379, Train Acc: 56.14%
#   Val   Loss: 0.9970, Val   Acc: 51.99%
# Epoch 14/30
#   Train Loss: 0.9277, Train Acc: 56.75%
#   Val   Loss: 1.0122, Val   Acc: 52.32%
# Epoch 15/30
#   Train Loss: 0.9184, Train Acc: 57.84%
#   Val   Loss: 1.0495, Val   Acc: 49.47%
# Epoch 16/30
#   Train Loss: 0.9129, Train Acc: 58.17%
#   Val   Loss: 1.0164, Val   Acc: 51.00%
# Epoch 17/30
#   Train Loss: 0.9070, Train Acc: 58.05%
#   Val   Loss: 1.0146, Val   Acc: 51.94%
# Epoch 18/30
#   Train Loss: 0.9069, Train Acc: 58.68%
#   Val   Loss: 1.0518, Val   Acc: 52.19%
# Epoch 19/30
#   Train Loss: 0.8995, Train Acc: 58.89%
#   Val   Loss: 1.0152, Val   Acc: 53.25%
# Epoch 20/30
#   Train Loss: 0.8925, Train Acc: 59.06%
#   Val   Loss: 1.0870, Val   Acc: 52.89%
# Epoch 21/30
#   Train Loss: 0.8900, Train Acc: 59.41%
#   Val   Loss: 1.1020, Val   Acc: 51.43%
# Epoch 22/30
#   Train Loss: 0.8923, Train Acc: 59.46%
#   Val   Loss: 1.0382, Val   Acc: 51.85%
# Epoch 23/30
#   Train Loss: 0.8829, Train Acc: 59.93%
#   Val   Loss: 1.1560, Val   Acc: 52.37%
# Epoch 24/30
#   Train Loss: 0.8821, Train Acc: 59.90%
#   Val   Loss: 1.1764, Val   Acc: 50.82%
# Epoch 25/30
#   Train Loss: 0.8754, Train Acc: 60.14%
#   Val   Loss: 1.0798, Val   Acc: 51.58%
# Epoch 26/30
#   Train Loss: 0.8701, Train Acc: 60.65%
#   Val   Loss: 1.0639, Val   Acc: 51.02%
# Epoch 27/30
#   Train Loss: 0.8754, Train Acc: 60.18%
#   Val   Loss: 1.0728, Val   Acc: 51.40%
# Epoch 28/30
#   Train Loss: 0.8661, Train Acc: 61.15%
#   Val   Loss: 1.1006, Val   Acc: 52.80%
# Epoch 29/30
#   Train Loss: 0.8607, Train Acc: 61.05%
#   Val   Loss: 1.1113, Val   Acc: 52.32%
# Epoch 30/30
#   Train Loss: 0.8634, Train Acc: 60.96%
#   Val   Loss: 1.1381, Val   Acc: 52.64%
# #### Normalized
# Epoch 1/30
#   Train Loss: 1.1049, Train Acc: 34.25%
#   Val   Loss: 1.0976, Val   Acc: 36.16%
# Epoch 2/30
#   Train Loss: 1.1008, Train Acc: 34.18%
#   Val   Loss: 1.1008, Val   Acc: 31.13%
# Epoch 3/30
#   Train Loss: 1.1033, Train Acc: 34.29%
#   Val   Loss: 1.0980, Val   Acc: 36.16%
# Epoch 4/30
#   Train Loss: 1.0991, Train Acc: 34.29%
#   Val   Loss: 1.0970, Val   Acc: 36.16%
# Epoch 5/30
#   Train Loss: 1.0991, Train Acc: 33.68%
#   Val   Loss: 1.0971, Val   Acc: 36.16%
# Epoch 6/30
#   Train Loss: 1.0993, Train Acc: 33.61%
#   Val   Loss: 1.0973, Val   Acc: 36.16%
# Epoch 7/30
#   Train Loss: 1.0993, Train Acc: 33.49%
#   Val   Loss: 1.0980, Val   Acc: 32.72%
# Epoch 8/30
#   Train Loss: 1.0993, Train Acc: 33.70%
#   Val   Loss: 1.0967, Val   Acc: 36.16%
# Epoch 9/30
#   Train Loss: 1.0990, Train Acc: 34.15%
#   Val   Loss: 1.0975, Val   Acc: 36.16%
# Epoch 10/30
#   Train Loss: 1.0993, Train Acc: 33.62%
#   Val   Loss: 1.0977, Val   Acc: 36.16%
# Epoch 11/30
#   Train Loss: 1.0990, Train Acc: 33.93%
#   Val   Loss: 1.0976, Val   Acc: 36.16%
# Epoch 12/30
#   Train Loss: 1.0990, Train Acc: 33.98%
#   Val   Loss: 1.0966, Val   Acc: 36.16%
# Epoch 13/30
#   Train Loss: 1.0991, Train Acc: 34.00%
#   Val   Loss: 1.0988, Val   Acc: 36.16%
# Epoch 14/30
#   Train Loss: 1.0991, Train Acc: 33.80%
#   Val   Loss: 1.0979, Val   Acc: 32.72%
# Epoch 15/30
#   Train Loss: 1.0992, Train Acc: 33.72%
#   Val   Loss: 1.0973, Val   Acc: 36.16%
# Epoch 16/30
#   Train Loss: 1.0992, Train Acc: 34.03%
#   Val   Loss: 1.0967, Val   Acc: 36.16%
# Epoch 17/30
#   Train Loss: 1.0989, Train Acc: 33.98%
#   Val   Loss: 1.0981, Val   Acc: 36.16%
# Epoch 18/30
#   Train Loss: 1.0990, Train Acc: 33.59%
#   Val   Loss: 1.0982, Val   Acc: 36.16%
# Epoch 19/30
#   Train Loss: 1.0991, Train Acc: 34.01%
#   Val   Loss: 1.1009, Val   Acc: 32.72%
# Epoch 20/30
#   Train Loss: 1.0992, Train Acc: 33.78%
#   Val   Loss: 1.0975, Val   Acc: 36.16%
# Epoch 21/30
#   Train Loss: 1.0991, Train Acc: 33.68%
#   Val   Loss: 1.1006, Val   Acc: 31.13%
# Epoch 22/30
#   Train Loss: 1.0992, Train Acc: 33.54%
#   Val   Loss: 1.1012, Val   Acc: 32.72%
# Epoch 23/30
#   Train Loss: 1.0990, Train Acc: 34.15%
#   Val   Loss: 1.0978, Val   Acc: 32.72%
# Epoch 24/30
#   Train Loss: 1.0993, Train Acc: 33.77%
#   Val   Loss: 1.0983, Val   Acc: 32.72%
# Epoch 25/30
#   Train Loss: 1.0989, Train Acc: 34.09%
#   Val   Loss: 1.0986, Val   Acc: 32.72%
# Epoch 26/30
#   Train Loss: 1.0988, Train Acc: 34.28%
#   Val   Loss: 1.0972, Val   Acc: 36.16%
# Epoch 27/30
#   Train Loss: 1.0991, Train Acc: 33.71%
#   Val   Loss: 1.0991, Val   Acc: 36.16%
# Epoch 28/30
#   Train Loss: 1.0991, Train Acc: 33.82%
#   Val   Loss: 1.0978, Val   Acc: 36.16%
# Epoch 29/30
#   Train Loss: 1.0989, Train Acc: 34.15%
#   Val   Loss: 1.0977, Val   Acc: 36.16%
# Epoch 30/30
#   Train Loss: 1.0995, Train Acc: 33.19%
#   Val   Loss: 1.0971, Val   Acc: 36.16%

# %% [markdown]
# ## K-Fold Cross-Validation
# TEST: ['chocoTaco', 'MataraKan', 'runthefutmarket', 'Joe_Bartolozzi', 'filian', 'Rainbow6', 'Zoomaa', 'Sweet_Anita', 'L3WG', 'Emongg', 'SmallAnt', 'TinaKitten', 'PENTA', 'fl0m', 'JackManifoldTV', 'KingWoolz', 'Jynxzi', 'ShahZaM', 'Nightblue3']
#
# ### Fold 1
# Epoch 1/30 | Train Loss: 1487.9083, Train Acc: 35.31% | Val Loss: 496.4833, Val Acc: 34.85%
# Epoch 2/30 | Train Loss: 1486.6936, Train Acc: 35.61% | Val Loss: 496.6021, Val Acc: 34.85%
# Epoch 3/30 | Train Loss: 1486.9848, Train Acc: 35.44% | Val Loss: 496.2302, Val Acc: 34.85%
# Epoch 4/30 | Train Loss: 1486.8734, Train Acc: 35.34% | Val Loss: 496.7953, Val Acc: 34.85%
# Epoch 5/30 | Train Loss: 1486.4569, Train Acc: 35.51% | Val Loss: 497.0466, Val Acc: 34.85%
# Epoch 6/30 | Train Loss: 1486.5214, Train Acc: 35.51% | Val Loss: 497.7298, Val Acc: 34.85%
# Epoch 7/30 | Train Loss: 1486.6414, Train Acc: 35.26% | Val Loss: 497.5975, Val Acc: 34.85%
# Epoch 8/30 | Train Loss: 1486.7300, Train Acc: 35.87% | Val Loss: 497.0403, Val Acc: 34.85%
# Epoch 9/30 | Train Loss: 1486.7852, Train Acc: 35.19% | Val Loss: 496.8974, Val Acc: 34.85%
# Epoch 10/30 | Train Loss: 1486.8639, Train Acc: 35.42% | Val Loss: 496.6022, Val Acc: 34.85%
# Epoch 11/30 | Train Loss: 1486.5793, Train Acc: 35.31% | Val Loss: 496.3175, Val Acc: 34.85%
# Epoch 12/30 | Train Loss: 1486.7955, Train Acc: 35.58% | Val Loss: 496.2824, Val Acc: 34.85%
# Epoch 13/30 | Train Loss: 1485.8514, Train Acc: 35.23% | Val Loss: 496.2347, Val Acc: 34.85%
# Epoch 14/30 | Train Loss: 1486.8094, Train Acc: 35.68% | Val Loss: 497.7163, Val Acc: 33.37%
# Epoch 15/30 | Train Loss: 1486.9596, Train Acc: 35.53% | Val Loss: 496.7613, Val Acc: 33.37%
# Epoch 16/30 | Train Loss: 1486.7279, Train Acc: 35.70% | Val Loss: 497.0130, Val Acc: 34.85%
# Epoch 17/30 | Train Loss: 1486.8343, Train Acc: 35.39% | Val Loss: 496.4975, Val Acc: 34.85%
# Epoch 18/30 | Train Loss: 1486.1502, Train Acc: 35.53% | Val Loss: 497.0276, Val Acc: 34.85%
# Epoch 19/30 | Train Loss: 1486.9757, Train Acc: 35.27% | Val Loss: 497.9113, Val Acc: 34.85%
# Epoch 20/30 | Train Loss: 1487.0625, Train Acc: 35.27% | Val Loss: 496.4441, Val Acc: 34.85%
# Epoch 21/30 | Train Loss: 1486.7133, Train Acc: 35.25% | Val Loss: 496.3288, Val Acc: 34.85%
# Epoch 22/30 | Train Loss: 1487.0487, Train Acc: 35.46% | Val Loss: 496.5400, Val Acc: 34.85%
# Epoch 23/30 | Train Loss: 1486.5851, Train Acc: 35.26% | Val Loss: 496.2784, Val Acc: 34.85%
# Epoch 24/30 | Train Loss: 1486.8177, Train Acc: 35.40% | Val Loss: 497.8041, Val Acc: 31.79%
# Epoch 25/30 | Train Loss: 1486.9339, Train Acc: 35.48% | Val Loss: 496.3612, Val Acc: 34.85%
# Epoch 26/30 | Train Loss: 1486.4975, Train Acc: 35.73% | Val Loss: 496.6059, Val Acc: 33.37%
# Epoch 27/30 | Train Loss: 1486.6298, Train Acc: 35.26% | Val Loss: 496.5822, Val Acc: 34.85%
# Epoch 28/30 | Train Loss: 1486.6644, Train Acc: 35.35% | Val Loss: 496.4887, Val Acc: 34.85%
# Epoch 29/30 | Train Loss: 1486.9476, Train Acc: 35.33% | Val Loss: 497.9073, Val Acc: 34.85%
# Epoch 30/30 | Train Loss: 1487.1321, Train Acc: 35.69% | Val Loss: 496.2897, Val Acc: 34.85%
# Model for fold 1 saved to models\streamer_class_model_fold1.pth
#
# ### Fold 2
# Epoch 1/30 | Train Loss: 1485.7203, Train Acc: 35.53% | Val Loss: 497.3031, Val Acc: 35.87%
# Epoch 2/30 | Train Loss: 1487.1751, Train Acc: 35.24% | Val Loss: 496.1983, Val Acc: 35.48%
# Epoch 3/30 | Train Loss: 1487.7601, Train Acc: 34.80% | Val Loss: 496.3535, Val Acc: 35.48%
# Epoch 4/30 | Train Loss: 1486.9327, Train Acc: 35.18% | Val Loss: 496.0968, Val Acc: 35.48%
# Epoch 5/30 | Train Loss: 1486.8197, Train Acc: 35.10% | Val Loss: 496.2385, Val Acc: 32.96%
# Epoch 6/30 | Train Loss: 1486.7796, Train Acc: 34.94% | Val Loss: 496.4066, Val Acc: 35.48%
# Epoch 7/30 | Train Loss: 1486.8668, Train Acc: 35.40% | Val Loss: 496.2112, Val Acc: 35.48%
# Epoch 8/30 | Train Loss: 1487.1315, Train Acc: 35.18% | Val Loss: 496.1270, Val Acc: 35.48%
# Epoch 9/30 | Train Loss: 1487.3283, Train Acc: 34.99% | Val Loss: 496.2777, Val Acc: 35.48%
# Epoch 10/30 | Train Loss: 1486.8681, Train Acc: 35.29% | Val Loss: 496.2066, Val Acc: 35.48%
# Epoch 11/30 | Train Loss: 1487.0672, Train Acc: 35.05% | Val Loss: 496.0628, Val Acc: 35.48%
# Epoch 12/30 | Train Loss: 1486.7741, Train Acc: 35.06% | Val Loss: 496.1746, Val Acc: 35.48%
# Epoch 13/30 | Train Loss: 1487.3310, Train Acc: 35.35% | Val Loss: 496.0069, Val Acc: 35.48%
# Epoch 14/30 | Train Loss: 1486.8465, Train Acc: 35.10% | Val Loss: 496.6829, Val Acc: 32.96%
# Epoch 15/30 | Train Loss: 1487.2440, Train Acc: 35.07% | Val Loss: 496.4327, Val Acc: 35.48%
# Epoch 16/30 | Train Loss: 1486.7519, Train Acc: 35.17% | Val Loss: 497.1733, Val Acc: 32.96%
# Epoch 17/30 | Train Loss: 1487.6341, Train Acc: 35.13% | Val Loss: 496.0568, Val Acc: 35.48%
# Epoch 18/30 | Train Loss: 1487.2071, Train Acc: 35.22% | Val Loss: 496.0574, Val Acc: 35.48%
# Epoch 19/30 | Train Loss: 1486.7344, Train Acc: 35.28% | Val Loss: 496.5731, Val Acc: 32.96%
# Epoch 20/30 | Train Loss: 1487.4358, Train Acc: 35.16% | Val Loss: 496.0704, Val Acc: 35.48%
# Epoch 21/30 | Train Loss: 1487.0432, Train Acc: 35.11% | Val Loss: 496.3613, Val Acc: 35.48%
# Epoch 22/30 | Train Loss: 1487.1088, Train Acc: 35.20% | Val Loss: 496.3971, Val Acc: 32.96%
# Epoch 23/30 | Train Loss: 1486.8340, Train Acc: 35.16% | Val Loss: 496.6487, Val Acc: 35.48%
# Epoch 24/30 | Train Loss: 1487.3848, Train Acc: 35.14% | Val Loss: 496.4299, Val Acc: 35.48%
# Epoch 25/30 | Train Loss: 1487.4406, Train Acc: 35.26% | Val Loss: 496.6198, Val Acc: 35.48%
# Epoch 26/30 | Train Loss: 1487.3663, Train Acc: 34.97% | Val Loss: 496.2919, Val Acc: 35.48%
# Epoch 27/30 | Train Loss: 1487.1546, Train Acc: 35.16% | Val Loss: 496.4109, Val Acc: 35.48%
# Epoch 28/30 | Train Loss: 1487.0993, Train Acc: 35.04% | Val Loss: 496.2249, Val Acc: 35.48%
# Epoch 29/30 | Train Loss: 1487.1798, Train Acc: 35.34% | Val Loss: 496.1720, Val Acc: 35.48%
# Epoch 30/30 | Train Loss: 1487.3912, Train Acc: 34.99% | Val Loss: 496.3017, Val Acc: 35.48%
# Model for fold 2 saved to models\streamer_class_model_fold2.pth
#
# ### Fold 3
# Epoch 1/30 | Train Loss: 1493.1885, Train Acc: 34.66% | Val Loss: 496.2135, Val Acc: 36.60%
# Epoch 2/30 | Train Loss: 1487.4880, Train Acc: 34.78% | Val Loss: 495.6041, Val Acc: 36.60%
# Epoch 3/30 | Train Loss: 1488.2842, Train Acc: 34.66% | Val Loss: 495.5216, Val Acc: 36.60%
# Epoch 4/30 | Train Loss: 1487.3782, Train Acc: 34.96% | Val Loss: 496.8323, Val Acc: 31.82%
# Epoch 5/30 | Train Loss: 1487.4493, Train Acc: 34.71% | Val Loss: 495.9654, Val Acc: 36.60%
# Epoch 6/30 | Train Loss: 1487.5910, Train Acc: 34.68% | Val Loss: 496.2727, Val Acc: 31.82%
# Epoch 7/30 | Train Loss: 1487.4355, Train Acc: 34.68% | Val Loss: 496.0997, Val Acc: 36.60%
# Epoch 8/30 | Train Loss: 1487.2943, Train Acc: 34.51% | Val Loss: 496.2951, Val Acc: 36.60%
# Epoch 9/30 | Train Loss: 1487.6228, Train Acc: 34.44% | Val Loss: 495.7338, Val Acc: 36.60%
# Epoch 10/30 | Train Loss: 1487.2980, Train Acc: 34.61% | Val Loss: 495.8167, Val Acc: 36.60%
# Epoch 11/30 | Train Loss: 1487.3649, Train Acc: 34.95% | Val Loss: 495.6007, Val Acc: 36.60%
# Epoch 12/30 | Train Loss: 1487.0401, Train Acc: 35.09% | Val Loss: 495.8581, Val Acc: 36.60%
# Epoch 13/30 | Train Loss: 1487.0997, Train Acc: 34.36% | Val Loss: 495.6574, Val Acc: 36.60%
# Epoch 14/30 | Train Loss: 1487.5248, Train Acc: 34.61% | Val Loss: 495.8703, Val Acc: 36.60%
# Epoch 15/30 | Train Loss: 1487.5670, Train Acc: 34.63% | Val Loss: 496.0949, Val Acc: 36.60%
# Epoch 16/30 | Train Loss: 1487.4355, Train Acc: 34.92% | Val Loss: 495.8765, Val Acc: 36.60%
# Epoch 17/30 | Train Loss: 1487.1097, Train Acc: 34.54% | Val Loss: 497.0880, Val Acc: 31.82%
# Epoch 18/30 | Train Loss: 1487.3686, Train Acc: 34.60% | Val Loss: 495.8060, Val Acc: 36.60%
# Epoch 19/30 | Train Loss: 1487.4542, Train Acc: 34.55% | Val Loss: 495.7754, Val Acc: 36.60%
# Epoch 20/30 | Train Loss: 1487.4934, Train Acc: 34.65% | Val Loss: 497.0281, Val Acc: 31.82%
# Epoch 21/30 | Train Loss: 1487.3323, Train Acc: 34.91% | Val Loss: 497.4748, Val Acc: 36.60%
# Epoch 22/30 | Train Loss: 1487.3339, Train Acc: 35.08% | Val Loss: 495.8807, Val Acc: 36.60%
# Epoch 23/30 | Train Loss: 1487.3739, Train Acc: 34.89% | Val Loss: 495.8959, Val Acc: 36.60%
# Epoch 24/30 | Train Loss: 1487.7684, Train Acc: 34.72% | Val Loss: 495.8651, Val Acc: 36.60%
# Epoch 25/30 | Train Loss: 1487.3601, Train Acc: 34.57% | Val Loss: 496.7048, Val Acc: 31.82%
# Epoch 26/30 | Train Loss: 1487.4601, Train Acc: 34.71% | Val Loss: 495.6931, Val Acc: 36.60%
# Epoch 27/30 | Train Loss: 1487.4609, Train Acc: 35.00% | Val Loss: 496.0449, Val Acc: 36.60%
# Epoch 28/30 | Train Loss: 1487.4518, Train Acc: 34.78% | Val Loss: 495.5985, Val Acc: 36.60%
# Epoch 29/30 | Train Loss: 1487.5615, Train Acc: 34.74% | Val Loss: 495.5012, Val Acc: 36.60%
# Epoch 30/30 | Train Loss: 1487.4671, Train Acc: 34.78% | Val Loss: 495.7147, Val Acc: 36.60%
# Model for fold 3 saved to models\streamer_class_model_fold3.pth
#
# ### Fold 4
# Epoch 1/30 | Train Loss: 1488.3555, Train Acc: 36.62% | Val Loss: 490.9305, Val Acc: 38.95%
# Epoch 2/30 |s Train Los: 1465.0041, Train Acc: 39.99% | Val Loss: 492.5517, Val Acc: 38.79%
# Epoch 3/30 | Train Loss: 1455.4914, Train Acc: 41.29% | Val Loss: 481.5785, Val Acc: 42.44%
# Epoch 4/30 | Train Loss: 1439.4828, Train Acc: 42.92% | Val Loss: 524.4701, Val Acc: 42.00%
# Epoch 5/30 | Train Loss: 1431.0164, Train Acc: 43.75% | Val Loss: 481.9991, Val Acc: 42.73%
# Epoch 6/30 | Train Loss: 1424.6226, Train Acc: 43.72% | Val Loss: 478.9541, Val Acc: 42.21%
# Epoch 7/30 | Train Loss: 1418.2693, Train Acc: 44.43% | Val Loss: 479.7469, Val Acc: 44.59%
# Epoch 8/30 | Train Loss: 1412.7674, Train Acc: 44.86% | Val Loss: 476.0362, Val Acc: 43.44%
# Epoch 9/30 | Train Loss: 1414.2562, Train Acc: 44.63% | Val Loss: 480.8001, Val Acc: 43.04%
# Epoch 10/30 | Train Loss: 1411.1602, Train Acc: 44.67% | Val Loss: 484.2031, Val Acc: 41.79%
# Epoch 11/30 | Train Loss: 1407.2609, Train Acc: 45.09% | Val Loss: 471.9536, Val Acc: 44.33%
# Epoch 12/30 | Train Loss: 1409.6774, Train Acc: 44.86% | Val Loss: 470.6227, Val Acc: 44.08%
# Epoch 13/30 | Train Loss: 1402.2770, Train Acc: 44.76% | Val Loss: 471.4035, Val Acc: 44.40%
# Epoch 14/30 | Train Loss: 1401.2931, Train Acc: 45.37% | Val Loss: 473.3198, Val Acc: 44.04%
# Epoch 15/30 | Train Loss: 1400.7412, Train Acc: 45.62% | Val Loss: 472.5059, Val Acc: 44.05%
# Epoch 16/30 | Train Loss: 1393.3469, Train Acc: 45.97% | Val Loss: 473.5442, Val Acc: 44.92%
# Epoch 17/30 | Train Loss: 1392.6745, Train Acc: 45.96% | Val Loss: 477.2011, Val Acc: 43.50%
# Epoch 18/30 | Train Loss: 1399.7284, Train Acc: 45.43% | Val Loss: 479.5761, Val Acc: 42.78%
# Epoch 19/30 | Train Loss: 1415.1872, Train Acc: 44.06% | Val Loss: 477.9207, Val Acc: 42.82%
# Epoch 20/30 | Train Loss: 1398.4653, Train Acc: 45.42% | Val Loss: 481.5096, Val Acc: 42.32%
# Epoch 21/30 | Train Loss: 1395.5250, Train Acc: 45.01% | Val Loss: 474.1188, Val Acc: 44.52%
# Epoch 22/30 | Train Loss: 1387.4028, Train Acc: 45.64% | Val Loss: 477.5795, Val Acc: 43.91%
# Epoch 23/30 | Train Loss: 1387.0173, Train Acc: 45.51% | Val Loss: 470.8931, Val Acc: 44.56%
# Epoch 24/30 | Train Loss: 1392.5729, Train Acc: 45.03% | Val Loss: 473.3908, Val Acc: 43.75%
# Epoch 27/30 | Train Loss: 1388.3826, Train Acc: 45.79% | Val Loss: 470.1441, Val Acc: 44.41%
# Epoch 28/30 | Train Loss: 1378.6255, Train Acc: 46.28% | Val Loss: 477.3977, Val Acc: 43.77%
# Epoch 29/30 | Train Loss: 1376.8795, Train Acc: 46.40% | Val Loss: 476.0564, Val Acc: 45.81%
# Epoch 30/30 | Train Loss: 1375.4032, Train Acc: 46.49% | Val Loss: 478.0802, Val Acc: 45.45%
# Model for fold 4 saved to models\streamer_class_model_fold4.pth
#
# ### Overall
# Avg Train Loss: 1459.3484, Avg Train Accuracy: 37.99%
# Avg Validation Loss: 491.5966, Avg Validation Accuracy: 38.09%

# %% [markdown]
# # Testing Classification
